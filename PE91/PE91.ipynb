# %%
#[(0,0), (1,1), (0,2)] is implicitly the same as [(1,1),(0,2)]

points = [(1,1),(0,2)]


def side_lengths(points):
    asdf

# %%
import math, itertools as it

L = 100
ans = 3*L*L
for x, y in it.product(range(1, L+1), repeat=2):
    g = math.gcd(x, y)
    ans += 2 * min(g*(L-x)//y, g*y//x)
print(ans)
# Out:
# 62848
