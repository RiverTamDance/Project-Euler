# %%
len([1, 4, 6, 8, 8, 12, 12, 12, 15, 16, 16, 16, 18, 20, 24, 24, 24, 24, 24, 28, 27, 32, 30, 48, 32, 32, 32, 36, 36, 36, 42, 40, 40, 48, 48, 48, 45, 48, 48, 48, 48, 48, 54, 60, 54, 56, 54, 60, 63, 60, 60, 60, 63, 64, 64, 64, 64, 64, 70, 72, 72, 72, 72, 72, 72, 84, 80, 80, 81, 80, 80])
# Out:
# 71

# %%
from collections import Counter
import random

bag = Counter([5])

bag[5] += 1
i=0
for el in bag:
    i+=1
print(i)
print(bag)

bag_2 = Counter(bag)
print(bag_2)

bags = []
for t in range(6):
    new_bag = Counter(bag) 
    new_bag.update([random.randint(1,10)])
    bags.append(new_bag)

print(bags)
# Out:
# 1
# Counter({5: 2})
# Counter({5: 2})
# [Counter({5: 2, 8: 1}), Counter({5: 2, 2: 1}), Counter({5: 2, 9: 1}), Counter({5: 2, 10: 1}), Counter({5: 2, 2: 1}), Counter({5: 2, 3: 1})]

# %%
c = Counter([5,3])

c[5] -= 1

for el in c:
    print(c[el])
# Out:
# 0
# 1

# %%
if new_element != root_num:

# %%
print((5,))
# Out:
# (5,)

# %%
c = Counter({2:3,3:1, 4:0})
print(c)
print(+c)
print(c)
c= +c
print(c)
# Out:
# Counter({2: 3, 3: 1, 4: 0})
# Counter({2: 3, 3: 1})
# Counter({2: 3, 3: 1, 4: 0})
# Counter({2: 3, 3: 1})

# %%
t = [1,2,3,4,5]

print(list(range(1,len(t))))
# Out:
# 4
