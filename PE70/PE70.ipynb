# %%
t = sorted("09871234")
print(t)
# Out:
# ['0', '1', '2', '3', '4', '7', '8', '9']

# %%
import itertools as it
d = {1:[2,2], 3:[4,3], 5:[6,666]}
l = list(zip(*d.items()))

#m = list(map(lambda x, *y: it.chain([x],*y), d.items()))

o = [[x[0]] + x[1] for x in d.items()]
print(o)
# Out:
# [[1, 2, 2], [3, 4, 3], [5, 6, 666]]

# %%
import itertools as it

print(list(it.combinations_with_replacement([1,2,3,4],2)))
# Out:
# [(1, 1), (1, 2), (1, 3), (1, 4), (2, 2), (2, 3), (2, 4), (3, 3), (3, 4), (4, 4)]

# %%
l = [(653902, 326950), (652318, 326158), (632518, 316258), (599902, 299950), (599002, 299500), (502198, 251098), (502126, 251062), (500218, 250108), (326518, 163258), (312658, 156328), (259918, 129958), (259018, 129508), (251926, 125962), (250126, 125062), (210526, 105262), (205126, 102562), (59002, 29500), (25918, 12958), (21058, 10528), (20518, 10258), (2518, 1258), (502, 250), (974667, 649776), (865479, 576984), (706449, 470964), (654231, 436152), (653043, 435360), (650343, 433560), (569397, 379596), (539967, 359976), (539697, 359796), (534621, 356412), (166017, 110676), (152301, 101532), (56937, 37956), (53967, 35976), (5637, 3756), (5367, 3576), (2991, 1992), (291, 192), (21, 12), (869965, 695968), (708865, 567088), (657205, 525760), (544435, 435544), (431485, 345184), (181465, 145168), (86965, 69568), (49435, 39544), (44305, 35440), (4435, 3544), (780109, 709180), (590623, 536920), (582109, 529180), (384109, 349180), (285109, 259180), (87109, 79180), (852091, 801952), (167569, 157696), (119221, 112192), (35683, 33568), (674521, 645172), (452203, 432520), (157021, 150172), (22471, 21472), (615409, 594160), (940417, 917440), (243007, 237040), (201679, 196720), (114109, 111904), (69271, 67912), (45421, 44512), (20617, 20176), (848833, 834388), (94813, 93148), (440413, 434140), (140083, 138040), (736297, 727936), (199627, 197296), (84283, 83248), (779281, 771892), (746539, 739456), (212101, 210112), (116503, 115360), (525121, 521152), (261259, 259216), (224269, 222496), (162619, 161296), (75841, 75184), (504601, 501604), (182401, 181204), (818053, 813580), (277621, 276172), (866527, 862576), (400993, 399040), (842389, 838924), (449467, 447496), (734101, 731104), (409687, 407896), (661579, 659176), (176569, 175696), (579067, 577096), (400399, 399040), (284029, 282940), (474883, 473488), (880567, 878560), (732031, 730312), (778669, 776896), (783169, 781396)]

best = [float('inf'),0,0]
for n,tot in l:
    if n/tot < best[0]:
        best = [n/tot,n,tot]

print(best)
# Out:
# [1.0022690159662961, 783169, 781396]

# %%
from collections import defaultdict

D = defaultdict(set)
D[1] = 2
D[3] = 10
print(D["c"])
print(D)
# Out:
# set()
# defaultdict(<class 'set'>, {1: 2, 3: 10, 'c': set()})

# %%
not set()
# Out:
# True

# %%
from collections import defaultdict
def prime_factors(n):
    """finds all prime factors for all numbers less than n"""
    D = defaultdict(set)
    for i in range(2,n):
        if not D[i]:
            s = i
            while s < n:
                D[s].add(i)
                s += i 
    return(D)

prime_factors(100)
# Out:
# defaultdict(set,
#             {2: {2},
#              4: {2},
#              6: {2, 3},
#              8: {2},
#              10: {2, 5},
#              12: {2, 3},
#              14: {2, 7},
#              16: {2},
#              18: {2, 3},
#              20: {2, 5},
#              22: {2, 11},
#              24: {2, 3},
#              26: {2, 13},
#              28: {2, 7},
#              30: {2, 3, 5},
#              32: {2},
#              34: {2, 17},
#              36: {2, 3},
#              38: {2, 19},
#              40: {2, 5},
#              42: {2, 3, 7},
#              44: {2, 11},
#              46: {2, 23},
#              48: {2, 3},
#              50: {2, 5},
#              52: {2, 13},
#              54: {2, 3},
#              56: {2, 7},
#              58: {2, 29},
#              60: {2, 3, 5},
#              62: {2, 31},
#              64: {2},
#              66: {2, 3, 11},
#              68: {2, 17},
#              70: {2, 5, 7},
#              72: {2, 3},
# ...
