# %%
import itertools


def rect(m,n):
    result = (1/4)*(n**2+n)*(m**2+m)
    return(result)

sols=[]
for m in range(45, 2001):
    n = 0
    smaller =True
    while smaller:
        n += 1
        smaller = rect(n,m) < 2000000
    sols.extend([(n-1,m),(n,m)])
        
def closest(lst,target):
    current_best = 10000
    for n,m in lst:
        
        
        
        
d = dict()
print(sols)
# Out:
# [(61, 45), (62, 45), (60, 46), (61, 46), (59, 47), (60, 47), (57, 48), (58, 48), (56, 49), (57, 49), (55, 50), (56, 50), (54, 51), (55, 51), (53, 52), (54, 52), (52, 53), (53, 53), (51, 54), (52, 54), (50, 55), (51, 55), (49, 56), (50, 56), (48, 57), (49, 57), (47, 58), (48, 58), (47, 59), (48, 59), (46, 60), (47, 60), (45, 61), (46, 61), (44, 62), (45, 62), (44, 63), (45, 63), (43, 64), (44, 64), (42, 65), (43, 65), (42, 66), (43, 66), (41, 67), (42, 67), (40, 68), (41, 68), (40, 69), (41, 69), (39, 70), (40, 70), (39, 71), (40, 71), (38, 72), (39, 72), (37, 73), (38, 73), (37, 74), (38, 74), (36, 75), (37, 75), (36, 76), (37, 76), (36, 77), (37, 77), (35, 78), (36, 78), (35, 79), (36, 79), (34, 80), (35, 80), (34, 81), (35, 81), (33, 82), (34, 82), (33, 83), (34, 83), (32, 84), (33, 84), (32, 85), (33, 85), (32, 86), (33, 86), (31, 87), (32, 87), (31, 88), (32, 88), (31, 89), (32, 89), (30, 90), (31, 90), (30, 91), (31, 91), (30, 92), (31, 92), (29, 93), (30, 93), (29, 94), (30, 94
# ...
